# %%
from spider_setting import *
import requests
import pandas as pd
from datetime import datetime
import time,random
import fake_useragent
ua=fake_useragent.FakeUserAgent()
class MysqlDB():
    def __init__(self,user='buff',password='fiang123',host='106.14.66.39',port=3306,charset='utf8',db='buff',**params):
        from sqlalchemy import create_engine
        self.conn=create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{db}?charset={charset}',echo=True)
    def save_pd(self,val,table:str,columns=None,method:str='replace'):
        '''
        method append,replace
        '''
        if columns!=None:
            df=pd.DataFrame(val,columns=columns)
        else:
            df=pd.DataFrame(val)
        df.to_sql(table,self.conn,if_exists=method,index=False)
        return df
    def read_pd(self,table:str):
        df=pd.read_sql_table(con=self.conn,table_name=table)
        return df 
    def showtables(self):
        return self.conn.table_names()
    def getconn(self):
        return self.conn  
class BUFFSpider():
    
    def __init__(self,urls:list,headers:dict):
        #初始化结果列表和源代码列表
        self.res=[]
        self.pageSource=[]
        #初始化url列表和headers
        self.urls=urls
        self.headers=headers
    def getPage_source(self):
        
        for i,url in enumerate(self.urls):
            r=requests.get(url+f'&_={int(datetime.now().timestamp()*1000)}',headers=self.headers)
            try:
                self.pageSource+=r.json()['data']['items']
                print(f'第{i+1}页获取成功！')
            except:
                print(f'第{i+1}页获取失败！{r.json()}')
            time.sleep(random.randint(3,5))
    def parse(self,datas=None):
        
        if datas==None:
            datas=self.pageSource
        for d in datas:
            data=d.copy()
            #图片
            data['img']=d.get('goods_info').get('icon_url')
            #武器类型
            data['type']=d.get('goods_info').get('info').get('tags').get('type').get('localized_name')
            #磨损
            try:
                data['fray']=d.get('goods_info').get('info').get('tags').get('exterior').get('localized_name')
            except:
                #武器箱等道具没有磨损
                data['fray']=None
            #质量
            data['quality']=d.get('goods_info').get('info').get('tags').get('quality').get('localized_name')
            #稀有度
            data['rarity']=d.get('goods_info').get('info').get('tags').get('rarity').get('localized_name')
            data['time']=datetime.now()
            data.pop('goods_info')
            self.res.append(data)
    def run(self):
        
        self.getPage_source()
        self.parse()
        
#将字符串请求头转换为字典格式
def Headers(headers):
    headers=headers.replace(' ','').split('\n')
    keys=[]
    values=[]
    front=0
    for i in headers:
        key=[]
        value=[]
        for j,s in enumerate(list(i)):
            if front==0:
                if j!=0 and s==':':
                    front=1
                    continue
                key.append(s)
            else:
                value.append(s)
        keys.append(''.join(key))
        values.append(''.join(value))
        front=0
    return dict(zip(keys,values))   
   
if __name__ == '__main__':
    #获取全部页url和headers
    #网页buff商品数据api
    baseUrl='https://buff.163.com/api/market/goods'
    headers=Headers(f'''accept: application/json, text/javascript, */*; q=0.01
    Cookie:{cookies}
    referer: https://buff.163.com/market/csgo
    user-agent: {ua.edge}''')
    allpage=requests.get('https://buff.163.com/api/market/goods?game=csgo&page_num=1&use_suggestion=0&trigger=undefined_trigger&page_size=80',headers=headers).json()['data']['total_page']
    urls=[baseUrl + f'?game=csgo&page_num={i}&use_suggestion=0&trigger=undefined_trigger&page_size=80' for i in range(1,allpage+1)]
    BUFF=BUFFSpider(urls,headers)
    BUFF.run()
    #数据清洗并存入数据库
    df=pd.DataFrame(BUFF.res)
    df.buy_max_price=df.buy_max_price.astype('float64')
    df.market_min_price=df.market_min_price.astype('float64')
    df.quick_price=df.quick_price.astype('float64')
    df.sell_min_price=df.sell_min_price.astype('float64')
    df.sell_reference_price=df.sell_reference_price.astype('float64')
    MysqlDB(user=user,password=password,host=host,port=port,charset=charset,db=db).save_pd(df,'BUFF',method='append')
# Out:
# 第1页获取成功！
# 第2页获取失败！{'code': 'Login Required', 'error': '请先登录', 'extra': None}
# 第3页获取失败！{'code': 'Login Required', 'error': '请先登录', 'extra': None}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16688/2474703962.py in <module>
#     105     urls=[baseUrl + f'?game=csgo&page_num={i}&use_suggestion=0&trigger=undefined_trigger&page_size=80' for i in range(1,allpage+1)]
#     106     BUFF=BUFFSpider(urls,headers)
# --> 107     BUFF.run()
#     108     #数据清洗并存入数据库
#     109     df=pd.DataFrame(BUFF.res)
#
# ~\AppData\Local\Temp/ipykernel_16688/2474703962.py in run(self)
#      69     def run(self):
#      70
# ---> 71         self.getPage_source()
#      72         self.parse()
#      73
#
# ~\AppData\Local\Temp/ipykernel_16688/2474703962.py in getPage_source(self)
#      43             except:
#      44                 print(f'第{i+1}页获取失败！{r.json()}')
# ---> 45             time.sleep(random.randint(3,5))
#      46     def parse(self,datas=None):
#      47
#
# KeyboardInterrupt:

# %%
from datetime import datetime

# %%
1661852803091
1684413343968
# Out:
# 1684413343968

# %%
import pandas as pd
df=pd.DataFrame(BUFF.res)
df.buy_max_price=df.buy_max_price.astype('float64')
df.market_min_price=df.market_min_price.astype('float64')
df.quick_price=df.quick_price.astype('float64')
df.sell_min_price=df.sell_min_price.astype('float64')
df.sell_reference_price=df.sell_reference_price.astype('float64')

# %%
MysqlDB(user=user,password=password,host=host,port=port,charset=charset,db=db).save_pd(df,'BUFF',method='replace')
# Out:
# 2023-05-18 20:26:22,256 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-05-18 20:26:22,257 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-18 20:26:22,295 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-05-18 20:26:22,295 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-18 20:26:22,373 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-05-18 20:26:22,373 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-18 20:26:22,528 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2023-05-18 20:26:22,530 INFO sqlalchemy.engine.Engine [generated in 0.00083s] {'table_schema': 'buff', 'table_name': 'BUFF'}
# 2023-05-18 20:26:22,929 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2023-05-18 20:26:22,929 INFO sqlalchemy.engine.Engine [cached since 0.4008s ago] {'table_schema': 'buff', 'table_name': 'BUFF'}
# 2023-05-18 20:26:23,045 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `buff`
# 2023-05-18 20:26:23,045 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-18 20:26:23,093 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `BUFF`
# 2023-05-18 20:26:23,093 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-05-18 20:26:23,172 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-05-18 20:26:23,172 INFO sqlalchemy.engine.Engine
# DROP TABLE `BUFF`
# 2023-05-18 20:26:23,172 INFO sqlalchemy.engine.Engine [no key 0.00030s] {}
# 2023-05-18 20:26:23,226 INFO sqlalchemy.engine.Engine COMMIT
# 2023-05-18 20:26:23,303 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-05-18 20:26:23,303 INFO sqlalchemy.engine.Engine
# CREATE TABLE `BUFF` (
# 	appid BIGINT,
# 	bookmarked BOOL,
# 	buy_max_price FLOAT(53),
# 	buy_num BIGINT,
# 	can_bargain BOOL,
# 	can_search_by_tournament BOOL,
# 	description TEXT,
# 	game TEXT,
# 	has_buff_price_history BOOL,
# 	id BIGINT,
# 	market_hash_name TEXT,
# 	market_min_price FLOAT(53),
# 	name TEXT,
# 	quick_price FLOAT(53),
# 	sell_min_price FLOAT(53),
# 	sell_num BIGINT,
# 	sell_reference_price FLOAT(53),
# 	short_name TEXT,
# 	steam_market_url TEXT,
# 	transacted_num BIGINT,
# 	img TEXT,
# 	type TEXT,
# 	fray TEXT,
# 	quality TEXT,
# 	rarity TEXT,
# 	time DATETIME
# )
#
#
# 2023-05-18 20:26:23,306 INFO sqlalchemy.engine.Engine [no key 0.00040s] {}
# 2023-05-18 20:26:23,361 INFO sqlalchemy.engine.Engine COMMIT
# 2023-05-18 20:26:23,468 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-05-18 20:26:23,776 INFO sqlalchemy.engine.Engine INSERT INTO `BUFF` (appid, bookmarked, buy_max_price, buy_num, can_bargain, can_search_by_tournament, description, game, has_buff_price_history, id, market_hash_name, market_min_price, name, quick_price, sell_min_price, sell_num, sell_reference_price, short_name, steam_market_url, transacted_num, img, type, fray, quality, rarity, time) VALUES (%(appid)s, %(bookmarked)s, %(buy_max_price)s, %(buy_num)s, %(can_bargain)s, %(can_search_by_tournament)s, %(description)s, %(game)s, %(has_buff_price_history)s, %(id)s, %(market_hash_name)s, %(market_min_price)s, %(name)s, %(quick_price)s, %(sell_min_price)s, %(sell_num)s, %(sell_reference_price)s, %(short_name)s, %(steam_market_url)s, %(transacted_num)s, %(img)s, %(type)s, %(fray)s, %(quality)s, %(rarity)s, %(time)s)
# 2023-05-18 20:26:23,777 INFO sqlalchemy.engine.Engine [generated in 0.26080s] ({'appid': 730, 'bookmarked': 0, 'buy_max_price': 105.0, 'buy_num': 76, 'can_bargain': 1, 'can_search_by_tournament': 0, 'description': None, 'game': 'csgo', 'has_buff_price_history': 1, 'id': 928581, 'market_hash_name': 'Sticker | b1t (Gold) | Paris 2023', 'market_min_price': 0.0, 'name': '印花 | b1t（金色）| 2023年巴黎锦标赛', 'quick_price': 145.0, 'sell_min_price': 145.5, 'sell_num': 39, 'sell_reference_price': 145.5, 'short_name': '印花 | b1t（金色）| 2023年巴黎锦标赛', 'steam_market_url': 'https://steamcommunity.com/market/listings/730/Sticker%20%7C%20b1t%20%28Gold%29%20%7C%20Paris%202023', 'transacted_num': 0, 'img': 'https://g.fp.ps.netease.com/market/file/645453ef2b1fce0d4181626f86uTx1vD04', 'type': '印花', 'fray': None, 'quality': '普通', 'rarity': '非凡', 'time': datetime.datetime(2023, 5, 18, 20, 12, 18, 401607)}, {'appid': 730, 'bookmarked': 0, 'buy_max_price': 2.2, 'buy_num': 218, 'can_bargain': 1, 'can_search_by_tournament': 0, 'description': None, 'game': 'csgo', 'has_buff_price_history': 1, 'id': 900560, 'market_hash_name': 'StatTrak™ MAC-10 | Monkeyflage (Minimal Wear)', 'market_min_price': 0.0, 'name': 'MAC-10（StatTrak™） | 萌猴迷彩 (略有磨损)', 'quick_price': 2.78, 'sell_min_price': 2.79, 'sell_num': 230, 'sell_reference_price': 2.79, 'short_name': 'MAC-10（StatTrak™） | 萌猴迷彩', 'steam_market_url': 'https://steamcommunity.com/market/listings/730/StatTrak%E2%84%A2%20MAC-10%20%7C%20Monkeyflage%20%28Minimal%20Wear%29', 'transacted_num': 0, 'img': 'https://g.fp.ps.netease.com/market/file/62bf6edb7f559b672b147ca5Gl9VDhyi04', 'type': '微型冲锋枪', 'fray': '略有磨损', 'quality': 'StatTrak™', 'rarity': '军规级', 'time': datetime.datetime(2023, 5, 18, 20, 12, 18, 401607)}, {'appid': 730, 'bookmarked': 0, 'buy_max_price': 5.2, 'buy_num': 244, 'can_bargain': 1, 'can_search_by_tournament': 0, 'description': None, 'game': 'csgo', 'has_buff_price_history': 1, 'id': 900478, 'market_hash_name': 'M249 | Downtown (Field-Tested)', 'market_min_price': 0.0, 'name': 'M249 | 闹市区 (久经沙场)', 'quick_price': 5.19, 'sell_min_price': 5.19, 'sell_num': 2064, 'sell_reference_price': 5.2, 'short_name': 'M249 | 闹市区', 'steam_market_url': 'https://steamcommunity.com/market/listings/730/M249%20%7C%20Downtown%20%28Field-Tested%29', 'transacted_num': 0, 'img': 'https://g.fp.ps.netease.com/market/file/62bf72db271e677f552a202eWq8D2XwC04', 'type': '机枪', 'fray': '久经沙场', 'quality': '普通', 'rarity': '受限', 'time': datetime.datetime(2023, 5, 18, 20, 12, 18, 401607)}, {'appid': 730, 'bookmarked': 0, 'buy_max_price': 4.6, 'buy_num': 8468, 'can_bargain': 1, 'can_search_by_tournament': 0, 'description': None, 'game': 'csgo', 'has_buff_price_history': 1, 'id': 900464, 'market_hash_name': 'Recoil Case', 'market_min_price': 0.0, 'name': '反冲武器箱', 'quick_price': 4.59, 'sell_min_price': 4.59, 'sell_num': 45463, 'sell_reference_price': 4.6, 'short_name': '反冲武器箱', 'steam_market_url': 'https://steamcommunity.com/market/listings/730/Recoil%20Case', 'transacted_num': 0, 'img': 'https://g.fp.ps.netease.com/market/file/62bf6ac991df682427d38ac4MbtVXRUV04', 'type': '武器箱', 'fray': None, 'quality': '普通', 'rarity': '普通级', 'time': datetime.datetime(2023, 5, 18, 20, 12, 18, 401607)}, {'appid': 730, 'bookmarked': 0, 'buy_max_price': 56.0, 'buy_num': 43, 'can_bargain': 1, 'can_search_by_tournament': 0, 'description': None, 'game': 'csgo', 'has_buff_price_history': 1, 'id': 857627, 'market_hash_name': 'StatTrak™ AK-47 | Slate (Field-Tested)', 'market_min_price': 0.0, 'name': 'AK-47（StatTrak™） | 墨岩 (久经沙场)', 'quick_price': 58.78, 'sell_min_price': 58.88, 'sell_num': 2923, 'sell_reference_price': 58.88, 'short_name': 'AK-47（StatTrak™） | 墨岩', 'steam_market_url': 'https://steamcommunity.com/market/listings/730/StatTrak%E2%84%A2%20AK-47%20%7C%20Slate%20%28Field-Tested%29', 'transacted_num': 0, 'img': 'https://g.fp.ps.netease.com/market/file/609090042786fd7344d12bf8a1SoVHIN03', 'type': '步枪', 'fray': '久经沙场', 'quality': 'StatTrak™', 'rarity': '受限', 'time': datetime.da ...
# 2023-05-18 20:26:47,116 INFO sqlalchemy.engine.Engine COMMIT
# 2023-05-18 20:26:47,235 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `buff`
# 2023-05-18 20:26:47,236 INFO sqlalchemy.engine.Engine [raw sql] {}
#        appid  bookmarked  buy_max_price  buy_num  can_bargain  \
# 0        730       False         105.00       76         True
# 1        730       False           2.20      218         True
# 2        730       False           5.20      244         True
# 3        730       False           4.60     8468         True
# 4        730       False          56.00       43         True
# ...      ...         ...            ...      ...          ...
# 19435    730       False           0.17       10         True
# 19436    730       False           0.28      298         True
# 19437    730       False           0.25       51         True
# 19438    730       False           0.20       10         True
# 19439    730       False           0.21       11         True
#
#        can_search_by_tournament description  game  has_buff_price_history  \
# 0                         False        None  csgo                    True
# 1                         False        None  csgo                    True
# 2                         False        None  csgo                    True
# 3                         False        None  csgo                    True
# 4                         False        None  csgo                    True
# ...                         ...         ...   ...                     ...
# 19435                     False        None  csgo                    True
# 19436                     False        None  csgo                    True
# 19437                     False        None  csgo                    True
# 19438                     False        None  csgo                    True
# 19439                     False        None  csgo                    True
#
#            id  ... sell_reference_price                short_name  \
# 0      928581  ...               145.50  印花 | b1t（金色）| 2023年巴黎锦标赛
# 1      900560  ...                 2.79  MAC-10（StatTrak™） | 萌猴迷彩
# 2      900478  ...                 5.20                M249 | 闹市区
# 3      900464  ...                 4.60                     反冲武器箱
# 4      857627  ...                58.88     AK-47（StatTrak™） | 墨岩
# ...       ...  ...                  ...                       ...
# 19435  774935  ...                 0.30           封装的涂鸦 | 1G (深绿)
# 19436  773540  ...                 0.30                 印花 | 老当益壮
# 19437  772335  ...                 0.30    印花 | aizy | 2019年柏林锦标赛
# 19438  772176  ...                 0.30  印花 | ottoNd | 2019年柏林锦标赛
# 19439  772055  ...                 0.30    印花 | gade | 2019年柏林锦标赛
#
#                                         steam_market_url  transacted_num  \
# 0      https://steamcommunity.com/market/listings/730...               0
# 1      https://steamcommunity.com/market/listings/730...               0
# 2      https://steamcommunity.com/market/listings/730...               0
# 3      https://steamcommunity.com/market/listings/730...               0
# 4      https://steamcommunity.com/market/listings/730...               0
# ...                                                  ...             ...
# 19435  https://steamcommunity.com/market/listings/730...               0
# 19436  https://steamcommunity.com/market/listings/730...               0
# 19437  https://steamcommunity.com/market/listings/730...               0
# 19438  https://steamcommunity.com/market/listings/730...               0
# 19439  https://steamcommunity.com/market/listings/730...               0
#
#                                                      img   type  fray  \
# 0      https://g.fp.ps.netease.com/market/file/645453...     印花  None
# 1      https://g.fp.ps.netease.com/market/file/62bf6e...  微型冲锋枪  略有磨损
# 2      https://g.fp.ps.netease.com/market/file/62bf72...     机枪  久经沙场
# 3      https://g.fp.ps.netease.com/market/file/62bf6a...    武器箱  None
# 4      https://g.fp.ps.netease.com/market/file/609090...     步枪  久经沙场
# ...                                                  ...    ...   ...
# 19435  https://g.fp.ps.netease.com/market/file/5dd331...     涂鸦  None
# 19436  https://g.fp.ps.netease.com/market/file/5daa18...     印花  None
# 19437  https://g.fp.ps.netease.com/market/file/5d5459...     印花  None
# 19438  https://g.fp.ps.netease.com/market/file/5d544d...     印花  None
# 19439  https://g.fp.ps.netease.com/market/file/5d544d...     印花  None
#
#          quality rarity                       time
# 0             普通     非凡 2023-05-18 20:12:18.401607
# 1      StatTrak™    军规级 2023-05-18 20:12:18.401607
# 2             普通     受限 2023-05-18 20:12:18.401607
# 3             普通    普通级 2023-05-18 20:12:18.401607
# 4      StatTrak™     受限 2023-05-18 20:12:18.401607
# ...          ...    ...                        ...
# 19435         普通    普通级 2023-05-18 20:12:18.465347
# 19436         普通     高级 2023-05-18 20:12:18.465347
# 19437         普通     高级 2023-05-18 20:12:18.465347
# 19438         普通     高级 2023-05-18 20:12:18.465347
# 19439         普通     高级 2023-05-18 20:12:18.465347
#
# [19440 rows x 26 columns]

# %%
df.iloc[0]
# Out:
# appid                                                                     730
# bookmarked                                                              False
# buy_max_price                                                           105.0
# buy_num                                                                    76
# can_bargain                                                              True
# can_search_by_tournament                                                False
# description                                                              None
# game                                                                     csgo
# has_buff_price_history                                                   True
# id                                                                     928581
# market_hash_name                            Sticker | b1t (Gold) | Paris 2023
# market_min_price                                                          0.0
# name                                                 印花 | b1t（金色）| 2023年巴黎锦标赛
# quick_price                                                             145.0
# sell_min_price                                                          145.5
# sell_num                                                                   39
# sell_reference_price                                                    145.5
# short_name                                           印花 | b1t（金色）| 2023年巴黎锦标赛
# steam_market_url            https://steamcommunity.com/market/listings/730...
# transacted_num                                                              0
# img                         https://g.fp.ps.netease.com/market/file/645453...
# type                                                                       印花
# fray                                                                     None
# quality                                                                    普通
# rarity                                                                     非凡
# time                                               2023-05-18 20:12:18.401607
# Name: 0, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     19440 non-null  int64
#  1   bookmarked                19440 non-null  bool
#  2   buy_max_price             19440 non-null  object
#  3   buy_num                   19440 non-null  int64
#  4   can_bargain               19440 non-null  bool
#  5   can_search_by_tournament  19440 non-null  bool
#  6   description               1 non-null      object
#  7   game                      19440 non-null  object
#  8   has_buff_price_history    19440 non-null  bool
#  9   id                        19440 non-null  int64
#  10  market_hash_name          19440 non-null  object
#  11  market_min_price          19440 non-null  object
#  12  name                      19440 non-null  object
#  13  quick_price               19440 non-null  object
#  14  sell_min_price            19440 non-null  object
#  15  sell_num                  19440 non-null  int64
#  16  sell_reference_price      19440 non-null  object
#  17  short_name                19440 non-null  object
#  18  steam_market_url          19440 non-null  object
#  19  transacted_num            19440 non-null  int64
#  20  img                       19440 non-null  object
#  21  type                      19440 non-null  object
#  22  fray                      12338 non-null  object
#  23  quality                   19440 non-null  object
#  24  rarity                    19440 non-null  object
#  25  time                      19440 non-null  datetime64[ns]
# dtypes: bool(4), datetime64[ns](1), int64(5), object(16)
# memory usage: 3.3+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     19440 non-null  int64
#  1   bookmarked                19440 non-null  bool
#  2   buy_max_price             19440 non-null  float64
#  3   buy_num                   19440 non-null  int64
#  4   can_bargain               19440 non-null  bool
#  5   can_search_by_tournament  19440 non-null  bool
#  6   description               1 non-null      object
#  7   game                      19440 non-null  object
#  8   has_buff_price_history    19440 non-null  bool
#  9   id                        19440 non-null  int64
#  10  market_hash_name          19440 non-null  object
#  11  market_min_price          19440 non-null  float64
#  12  name                      19440 non-null  object
#  13  quick_price               19440 non-null  float64
#  14  sell_min_price            19440 non-null  float64
#  15  sell_num                  19440 non-null  int64
#  16  sell_reference_price      19440 non-null  float64
#  17  short_name                19440 non-null  object
#  18  steam_market_url          19440 non-null  object
#  19  transacted_num            19440 non-null  int64
#  20  img                       19440 non-null  object
#  21  type                      19440 non-null  object
#  22  fray                      12338 non-null  object
#  23  quality                   19440 non-null  object
#  24  rarity                    19440 non-null  object
#  25  time                      19440 non-null  datetime64[ns]
# dtypes: bool(4), datetime64[ns](1), float64(5), int64(5), object(11)
# memory usage: 3.3+ MB

# %%
ua.edge

# %%
# Out:
# 'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.8810.3391 Safari/537.36 Edge/18.14383'
